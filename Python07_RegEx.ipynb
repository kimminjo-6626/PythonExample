# %%
import re
txt = "The rain in Spain"
x = re.findall("ai", txt)
print(x)
# Out:
# ['ai', 'ai']

# %%
import re
txt = "The rain in Spain"
x = re.findall("Portugal", txt)
print(x)
# Out:
# []

# %%
import re
txt = "The rain in Spain"
x = re.search("\s", txt)
print("The first white-space character is located in position:", x.start())
# Out:
# The first white-space character is located in position: 3
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\김민조\AppData\Local\Temp\ipykernel_10552\4009967224.py:3: SyntaxWarning: invalid escape sequence '\s'
#   x = re.search("\s", txt)

# %%
import re
txt = "The rain in Spain"
x = re.search("Portugal", txt)
print(x)
# Out:
# None

# %%
import re
txt = "The rain in Spain"
x = re.split("\s", txt)
print(x)
# Out:
# ['The', 'rain', 'in', 'Spain']
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\김민조\AppData\Local\Temp\ipykernel_10552\3697854446.py:3: SyntaxWarning: invalid escape sequence '\s'
#   x = re.split("\s", txt)

# %%
import re
txt = "The rain in Spain"
x = re.split("\s", txt, 1)
print(x)
# Out:
# ['The', 'rain in Spain']
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\김민조\AppData\Local\Temp\ipykernel_10552\3056546710.py:3: SyntaxWarning: invalid escape sequence '\s'
#   x = re.split("\s", txt, 1)
# C:\Users\김민조\AppData\Local\Temp\ipykernel_10552\3056546710.py:3: DeprecationWarning: 'maxsplit' is passed as positional argument
#   x = re.split("\s", txt, 1)

# %%
import re
txt = "The rain in Spain"
x = re.sub("\s", "9", txt, 2)
print(x)
# Out:
# The9rain9in Spain
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\김민조\AppData\Local\Temp\ipykernel_10552\331855729.py:3: SyntaxWarning: invalid escape sequence '\s'
#   x = re.sub("\s", "9", txt, 2)
# C:\Users\김민조\AppData\Local\Temp\ipykernel_10552\331855729.py:3: DeprecationWarning: 'count' is passed as positional argument
#   x = re.sub("\s", "9", txt, 2)

# %%
import re
txt = "The rain in Spain"
x = re.search(r"\bS\w+", txt)
print(x.span())
# Out:
# (12, 17)

# %%
txt = f"The price is 49 dollars"
print(txt)
# Out:
# The price is 49 dollars

# %%
price = 59
txt = f"The price is {price} dollars"
print(txt)
# Out:
# The price is 59 dollars

# %%
price = 59
txt = f"The price is {price:.2f} dollars"
print(txt)
# Out:
# The price is 59.00 dollars

# %%
txt = f"The price is {95:.2f} dollars"
print(txt)
# Out:
# The price is 95.00 dollars

# %%
txt = f"The price is {20 * 59} dollars"
print(txt)
# Out:
# The price is 1180 dollars

# %%
price = 59
tax = 0.25
txt = f"The price is {price + (price * tax)} dollars"
print(txt)
# Out:
# The price is 73.75 dollars

# %%
fruit = "apples"
txt = f"I love {fruit.upper()}"
print(txt)
# Out:
# I love APPLES

# %%
def myconverter(x):
   return x * 0.3048
txt = f"The plane is flying at a {myconverter(30000)} meter altitude"
print(txt)
# Out:
# The plane is flying at a 9144.0 meter altitude

# %%
price = 59000
txt = f"The price is {price:,} dollars"
print(txt)
# Out:
# The price is 59,000 dollars

# %%
price = 49
txt = "The price is {} dollars"
print(txt.format(price))
# Out:
# The price is 49 dollars

# %%
quantity = 3
itemno = 567
price = 49
myorder = "I want {} pieces of item number {} for {:.2f} dollars."
print(myorder.format(quantity, itemno, price))
# Out:
# I want 3 pieces of item number 567 for 49.00 dollars.

# %%
x = None
print(x)
# Out:
# None

# %%
x = None
print(type(x))
# Out:
# <class 'NoneType'>

# %%
result = None
if result is None:
 print("No result yet")
else:
 print("Result is ready")
# Out:
# No result yet
